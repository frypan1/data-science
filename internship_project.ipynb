# %% [markdown]
# <a href="https://colab.research.google.com/github/frypan1/data-science/blob/main/internship_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from datetime import date,timedelta,datetime

# %% [markdown]
# # Data Wrangling

# %%
data = pd.read_csv('/content/drive/MyDrive/internship_project/supermarket_sales - Sheet1.csv')
data
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
data.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# ...

# %%
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
data['Product line'].value_counts()
# Out:
# Product line
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: count, dtype: int64

# %%
data.keys()
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
data_numerics = data.select_dtypes(include=np.number)
data_cat = set(data.columns) - set(data_numerics)
print("Numeric Columns:\n",list(data_numerics))
print("Categorical Columns:\n",data_cat)
# Out:
# Numeric Columns:
#  ['Unit price', 'Quantity', 'Tax 5%', 'Total', 'cogs', 'gross margin percentage', 'gross income', 'Rating']
# Categorical Columns:
#  {'Product line', 'Payment', 'Customer type', 'Date', 'Gender', 'City', 'Invoice ID', 'Time', 'Branch'}

# %%
data.isna().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
date = pd.to_datetime(data["Date"], format='%m/%d/%Y').dt.date
data[['Date']] = data[['Date']].apply( lambda x: pd.to_datetime(x, format='%m/%d/%Y').dt.date)
print ('After  converting : ' ,data['Date'].dtypes)
# Out:
# After  converting :  object

# %%
data['Date']=pd.to_datetime(data['Date'], format='%Y-%m-%d')
print ('After  converting : ' ,data['Date'].dtypes)
# Out:
# After  converting :  datetime64[ns]

# %%
data['Date']
# Out:
# 0     2019-01-05
# 1     2019-03-08
# 2     2019-03-03
# 3     2019-01-27
# 4     2019-02-08
#          ...
# 995   2019-01-29
# 996   2019-03-02
# 997   2019-02-09
# 998   2019-02-22
# 999   2019-02-18
# Name: Date, Length: 1000, dtype: datetime64[ns]

# %%
data['Time'] = pd.to_datetime(data['Time'])
print ('After  converting : ' ,data['Time'].dtypes)
# Out:
# After  converting :  datetime64[ns]
# <ipython-input-14-de5fb8f264f8>:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['Time'] = pd.to_datetime(data['Time'])

# %%
data['Month'] = data['Date'].dt.month_name()
data['Month_Number'] = data['Date'].dt.month
data['Hour'] = data['Time'].dt.hour
data['Hour'].describe()
# Out:
# count    1000.000000
# mean       14.910000
# std         3.186857
# min        10.000000
# 25%        12.000000
# 50%        15.000000
# 75%        18.000000
# max        20.000000
# Name: Hour, dtype: float64

# %%
time = []
for i in data['Hour']:
    if i>9 and i < 13 :
        time.append('Morning')
    elif i> 12 and i < 18:
        time.append('Afternoon')
    else:
        time.append('Evening')
data['Day_time'] = time

# %%
data = data.drop(columns=[ 'Invoice ID', 'gross margin percentage'], axis=1)

# %%
data.shape
# Out:
# (1000, 19)

# %% [markdown]
# # EDA

# %%
tot_sales = int(data["Total"].sum())
avg_rating = round(data["Rating"].mean(),1)
star_rate = ":star:" * int(round(avg_rating,0))
avg_slaes_by_transcation = round(data["Total"].mean(),2)

tot_income = int(data["gross income"].sum())
prod = (data["Product line"].count())
qty = int(data["Quantity"].sum())

print("tot_sales: ",tot_sales )
print('\n'"avg_rating: ",avg_rating )
print('\n'"avg_sales_by_transcation: ",avg_slaes_by_transcation )
print('\n'"tot_income: ",tot_income )
print('\n'"prod categories: ",prod )
print('\n'"Sold qty: ",qty )
# Out:
# tot_sales:  322966
#
# avg_rating:  7.0
#
# avg_sales_by_transcation:  322.97
#
# tot_income:  15379
#
# prod categories:  1000
#
# Sold qty:  5510

# %% [markdown]
# TOTAL SALE FOR EACH DATE

# %%
tot_sales = pd.pivot_table(data, values = 'Total', index = 'Date', aggfunc = 'sum')
tot_sales.head()
# Out:
#                 Total
# Date
# 2019-01-01  4745.1810
# 2019-01-02  1945.5030
# 2019-01-03  2078.1285
# 2019-01-04  1623.6885
# 2019-01-05  3536.6835

# %%
sales_per_prod = data.groupby('Product line').agg({'Total':'sum'}).sort_values('Total')
print(sales_per_prod)
plt.figure(figsize=(15,6))
sns.lineplot(x='Product line',y='Total',data=sales_per_prod,linestyle='--',marker='o');
# Out:
#                              Total
# Product line
# Health and beauty       49193.7390
# Home and lifestyle      53861.9130
# Fashion accessories     54305.8950
# Electronic accessories  54337.5315
# Sports and travel       55122.8265
# Food and beverages      56144.8440

# %% [markdown]
# QUANTITY SOLD DURING EACH MONTH

# %%
data.Month.unique()
# Out:
# array(['January', 'March', 'February'], dtype=object)

# %%
sales_by_month = data.groupby(['Month','Month_Number']).agg({'Quantity':'sum'}).sort_values('Month_Number',ascending = False)
print(sales_by_month)
sns.lineplot(x='Month',y='Quantity',data=sales_by_month,linestyle='--',marker='o');
plt.grid(True)
# Out:
#                        Quantity
# Month    Month_Number
# March    3                 1891
# February 2                 1654
# January  1                 1965

# %% [markdown]
# TOTAL NUMBER OF SALE EACH MONTH

# %%
data.columns
# Out:
# Index(['Branch', 'City', 'Customer type', 'Gender', 'Product line',
#        'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date', 'Time', 'Payment',
#        'cogs', 'gross income', 'Rating', 'Month', 'Month_Number', 'Hour',
#        'Day_time'],
#       dtype='object')

# %%
data.Month.unique()
# Out:
# array(['January', 'March', 'February'], dtype=object)

# %%
sales_per_month = data.groupby(['Month','Month_Number']).agg({'Total':'sum'}).sort_values('Month_Number')
print(sales_per_month)
sns.set_theme(style='whitegrid')
sns.barplot(x='Month',y='Total',data=sales_per_month,hue='Month',palette='pastel')
plt.ylabel('Total Sales')
plt.title("Monthly Sales")
# Out:
#                             Total
# Month    Month_Number
# January  1             116291.868
# February 2              97219.374
# March    3             109455.507
# Text(0.5, 1.0, 'Monthly Sales')

# %% [markdown]
# TOTAL SALES BY CITY

# %%
sale_by_city = data.groupby('City').agg({'Total':'sum'})
print(sale_by_city)
sns.set_theme(style='whitegrid',palette='pastel')
sns.barplot(x='City',y='Total',data=sale_by_city,hue='City')
plt.ylabel('Total Sales')
plt.title('Total Sale by City')
# Out:
#                  Total
# City
# Mandalay   106197.6720
# Naypyitaw  110568.7065
# Yangon     106200.3705
# Text(0.5, 1.0, 'Total Sale by City')

# %% [markdown]
# TOTAL SALE PER BRANCH

# %%
data.columns
# Out:
# Index(['Branch', 'City', 'Customer type', 'Gender', 'Product line',
#        'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date', 'Time', 'Payment',
#        'cogs', 'gross income', 'Rating', 'Month', 'Month_Number', 'Hour',
#        'Day_time'],
#       dtype='object')

# %%
sale_per_branch = data.groupby("Branch").agg({'Total':'sum'})
print(sale_per_branch)
sns.set_theme(style='whitegrid',palette='pastel')
sns.barplot(x='Branch',y='Total',data=sale_per_branch,hue='Branch')
plt.ylabel('Total Sales')
plt.title('Sales by Branch')
# Out:
#               Total
# Branch
# A       106200.3705
# B       106197.6720
# C       110568.7065
# Text(0.5, 1.0, 'Sales by Branch')

# %% [markdown]
# What is the percentage of Sales contributed by each branch?

# %%
sales_percent_by_branch = sale_per_branch / sale_per_branch.sum()*100
print(sales_percent_by_branch)

plt.figure(figsize=(6, 6))
target =  sales_percent_by_branch.Total.tolist()
labels = sales_percent_by_branch.index.tolist()
plt.pie(x=target, labels=labels, colors=['lightpink', 'skyblue','lightgreen'], autopct='%1.1f%%', shadow=False, startangle=90,)
plt.title("Sales Percentage by Branch")
plt.legend(bbox_to_anchor=(1.05, 1),loc='upper left', borderaxespad=0.)
# Out:
#             Total
# Branch
# A       32.882757
# B       32.881921
# C       34.235322

# %% [markdown]
# What are average sales in each Product line by each Customer type(Member, Normal) ?

# %%
data.columns
# Out:
# Index(['Branch', 'City', 'Customer type', 'Gender', 'Product line',
#        'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date', 'Time', 'Payment',
#        'cogs', 'gross income', 'Rating', 'Month', 'Month_Number', 'Hour',
#        'Day_time'],
#       dtype='object')

# %%
grouped_sales = pd.DataFrame(data.groupby(['Product line','Customer type'])['Total'].agg(['sum','mean']))

avg_sale = grouped_sales['mean'].unstack()

avg_sale.plot(kind='barh')
sns.set_theme(style='whitegrid',palette='pastel')
plt.title('Average sales by Product line and Customer type')
plt.xlabel('Average Sales')
plt.ylabel('Product Line')
plt.legend(title='Customer type')
plt.legend(bbox_to_anchor=(1.05,1),loc='upper left', borderaxespad=0.);

# %%
tot_sale = grouped_sales['sum'].unstack()

tot_sale.plot(kind='barh')
sns.set_theme(style='whitegrid',palette='pastel')
plt.title('Total sales by Product line and Customer type')
plt.xlabel('Total Sales')
plt.ylabel('Product Line')
plt.legend(title='Customer Type')
plt.legend(bbox_to_anchor=(1.05,1),loc='upper left',borderaxespad=0.);

# %%
grouped_sale = pd.DataFrame(data.groupby(['Product line','Gender'])['Total'].agg(['sum','mean']))
grouped_sale
# Out:
#                                       sum        mean
# Product line           Gender
# Electronic accessories Female  27102.0225  322.643125
#                        Male    27235.5090  316.691965
# Fashion accessories    Female  30437.4000  317.056250
#                        Male    23868.4950  291.079207
# Food and beverages     Female  33170.9175  368.565750
#                        Male    22973.9265  273.499125
# Health and beauty      Female  18560.9865  290.015414
#                        Male    30632.7525  348.099460
# Home and lifestyle     Female  30036.8775  380.213639
#                        Male    23825.0355  294.136241
# Sports and travel      Female  28574.7210  324.712739
#                        Male    26548.1055  340.360327

# %%
avg_sales = grouped_sale['mean'].unstack()
avg_sales.plot(kind='bar')
sns.set_theme(style='whitegrid',palette='pastel')
plt.title('Average sales by product line and gender')
plt.xlabel('Product line')
plt.xticks(rotation=90)
plt.ylabel('Average Sales')
plt.legend(title='Gender')
plt.legend(bbox_to_anchor=(1.05,1),loc='upper left',borderaxespad=0.)

# %%
tot_sales = grouped_sale['mean'].unstack()
tot_sales.plot(kind='bar')
sns.set_theme(style='whitegrid',palette='pastel')
plt.title('Total Sales by Product type and Gender')
plt.xlabel('Product Line')
plt.xticks(rotation = 90)
plt.ylabel('Total Sales')
plt.legend(title='Gender')
plt.legend(bbox_to_anchor=(1.05,1),loc='upper left',borderaxespad=0.);

# %%
grouped_sales = pd.DataFrame(data.groupby(["Product line","City"])["Total"].agg(["sum", "mean"]))
avg_sales_grouped = grouped_sales['mean'].unstack()
ax = avg_sales_grouped.plot(kind='bar', figsize=(8, 5))
sns.set_theme(style="whitegrid", palette="pastel")
ax.set_xlabel('Product line')
ax.set_ylabel('Average Sales')
ax.set_title('Average Sales by Product Line and City')
ax.legend(title='City')
plt.legend(bbox_to_anchor=(1.05, 1),loc='upper left', borderaxespad=0.)

# %%
grouped_sales = pd.DataFrame(data.groupby(["Product line","Branch"])["Total"].agg(["sum", "mean"]))
avg_sales_grouped = grouped_sales['mean'].unstack()
ax = avg_sales_grouped.plot(kind='bar', figsize=(8, 5))
sns.set_theme(style="whitegrid", palette="pastel")
ax.set_xlabel('Product line')
ax.set_ylabel('Average Sales')
ax.set_title('Average Sales by Product Line and Branch')
ax.legend(title='Branch')
plt.legend(bbox_to_anchor=(1.05, 1),loc='upper left', borderaxespad=0.)

# %%
rating_by_prod = data.groupby('Product line')['Rating'].mean()
rating_by_prod
sns.set_theme(style='whitegrid',palette='pastel')
sns.barplot(x=rating_by_prod.index,y=rating_by_prod.values,hue=rating_by_prod.index)
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4, 5],
#  [Text(0, 0, 'Electronic accessories'),
#   Text(1, 0, 'Fashion accessories'),
#   Text(2, 0, 'Food and beverages'),
#   Text(3, 0, 'Health and beauty'),
#   Text(4, 0, 'Home and lifestyle'),
#   Text(5, 0, 'Sports and travel')])

# %%
rating_by_qty= data.groupby(data['Quantity'])['Rating'].mean()
rating_by_qty

sns.set_theme(style="whitegrid", palette="pastel")
ax = sns.barplot(x=rating_by_qty.index, y=rating_by_qty.values,hue=rating_by_qty.index)
ax.set(xlabel='Quantity', ylabel='Rating', title='Average rating by Quantity')
# Out:
# [Text(0.5, 0, 'Quantity'),
#  Text(0, 0.5, 'Rating'),
#  Text(0.5, 1.0, 'Average rating by Quantity')]

# %% [markdown]
# correlation between unit price and tax

# %%
corr = data['Unit price'].corr(data['Tax 5%'])
print('Correlation coefficient between unit price and tax:', corr)
sns.set_theme(style="whitegrid", palette="pastel")
sns.scatterplot(x='Unit price', y='Tax 5%', data=data)
plt.xlabel('Price')
plt.ylabel('Tax')
plt.title('Correlation between Price and Tax')
# Out:
# Correlation coefficient between unit price and tax: 0.633962088589069
# Text(0.5, 1.0, 'Correlation between Price and Tax')

# %%
data.columns
# Out:
# Index(['Branch', 'City', 'Customer type', 'Gender', 'Product line',
#        'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date', 'Time', 'Payment',
#        'cogs', 'gross income', 'Rating', 'Month', 'Month_Number', 'Hour',
#        'Day_time'],
#       dtype='object')

# %%
corr=data['Unit price'].corr(data['gross income'])
corr
sns.set_theme(style="whitegrid", palette="pastel")
sns.scatterplot(x='Unit price', y='gross income', data=data)
# Out:
# <Axes: xlabel='Unit price', ylabel='gross income'>

# %% [markdown]
# PAYMENT METHOD PIE

# %%
target =  data["Payment"].value_counts()
labels = data["Payment"].value_counts().index
plt.pie(x=target, labels=labels, colors=['lightpink', 'skyblue','lightgreen'], autopct='%1.2f%%', shadow=False, startangle=90,)
plt.title("Payment method Analysis")
plt.legend(bbox_to_anchor=(1.05, 1),loc='upper left', borderaxespad=0.)

# %% [markdown]
# # ML

# %%
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# %%
features = ['Branch', 'City', 'Customer type', 'Gender', 'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Payment', 'cogs', 'gross income']
target = 'Rating'
df = data[features + [target]]

# %%
df = pd.get_dummies(df)
X = df.drop(target, axis=1)
y = df[target]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((700, 25), (300, 25), (700,), (300,))

# %% [markdown]
# Linear Regression

# %%
model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print('Mean Squared Error:',f'{mse:.2f}')
# Out:
# Mean Squared Error: 3.02

# %%
model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print('Mean Squared Error:', f'{mse:.2f}')
# Out:
# Mean Squared Error: 3.36

# %%
dtree= DecisionTreeRegressor()
dtree.fit(X_train, y_train)
y_pred = dtree.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print('Mean Squared Error:', f'{mse:.2f}')
# Out:
# Mean Squared Error: 6.50

# %%
svr= SVR()
svr.fit(X_train, y_train)
y_pred = svr.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print('Mean Squared Error:', f'{mse:.2f}')
# Out:
# Mean Squared Error: 3.01
