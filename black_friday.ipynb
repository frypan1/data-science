# %% [markdown]
# <a href="https://colab.research.google.com/github/frypan1/data-science/blob/main/black_friday.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('/content/drive/MyDrive/black friday/train 3.csv')
data
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
data.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  5.500680e+05  550068.000000   550068.000000       550068.000000
# mean   1.003029e+06       8.076707        0.409653            5.404270
# std    1.727592e+03       6.522660        0.491770            3.936211
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001516e+06       2.000000        0.000000            1.000000
# 50%    1.003077e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       376430.000000       166821.000000  550068.000000
# mean             9.842329           12.668243    9263.968713
# std              5.086590            4.125338    5023.065394
# min              2.000000            3.000000      12.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %% [markdown]
# Product_Category_2 & Product_Category_3 can be converted into int

# %%
x = data.Product_Category_3.unique()
x
# Out:
# array([nan, 14., 17.,  5.,  4., 16., 15.,  8.,  9., 13.,  6., 12.,  3.,
#        18., 11., 10.])

# %%
np.std(x[1:])
# Out:
# 4.668571040003092

# %% [markdown]
# occupation and product categories are masked

# %%
data.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %% [markdown]
# say 21 occupations

# %%
data.Occupation.unique()
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6])

# %%
data.isna().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
shape = data.shape
shape
# Out:
# (550068, 12)

# %% [markdown]
# PERCENTAGE OF NULL VALUES

# %%
data.isna().sum() * 100 /shape[0]
# Out:
# User_ID                        0.000000
# Product_ID                     0.000000
# Gender                         0.000000
# Age                            0.000000
# Occupation                     0.000000
# City_Category                  0.000000
# Stay_In_Current_City_Years     0.000000
# Marital_Status                 0.000000
# Product_Category_1             0.000000
# Product_Category_2            31.566643
# Product_Category_3            69.672659
# Purchase                       0.000000
# dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          376430 non-null  float64
#  10  Product_Category_3          166821 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
data.Product_Category_2.unique()
# Out:
# array([nan,  6., 14.,  2.,  8., 15., 16., 11.,  5.,  3.,  4., 12.,  9.,
#        10., 17., 13.,  7., 18.])

# %%
data.Product_Category_2.describe()
# Out:
# count    376430.000000
# mean          9.842329
# std           5.086590
# min           2.000000
# 25%           5.000000
# 50%           9.000000
# 75%          15.000000
# max          18.000000
# Name: Product_Category_2, dtype: float64

# %%
df = data.copy()

# %%
# df.dropna(subset=['Product_Category_2','Product_Category_3'],inplace = True)
# df.isna().sum()

# %%
df.shape[0]
# Out:
# 550068

# %%
data.shape[0]/df.shape[0]
# Out:
# 1.0

# %%
data['Age']= np.where(data['Age'] == '0-17','child',np.where(data['Age'] == '18-25','young',np.where(data['Age'] == '26-35','middle',np.where(data['Age'] == '36-45','senior','old'))))
data
# Out:
#         User_ID Product_ID Gender     Age  Occupation City_Category  \
# 0       1000001  P00069042      F   child          10             A
# 1       1000001  P00248942      F   child          10             A
# 2       1000001  P00087842      F   child          10             A
# 3       1000001  P00085442      F   child          10             A
# 4       1000002  P00285442      M     old          16             C
# ...         ...        ...    ...     ...         ...           ...
# 550063  1006033  P00372445      M     old          13             B
# 550064  1006035  P00375436      F  middle           1             C
# 550065  1006036  P00375436      F  middle          15             B
# 550066  1006038  P00375436      F     old           1             C
# 550067  1006039  P00371644      F     old           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2               0                   3
# ...

# %%
gp = data.groupby(['Gender','Age']).agg({'Product_Category_2':pd.Series.mode , 'Product_Category_3':pd.Series.mode})
gp
# Out:
#                Product_Category_2  Product_Category_3
# Gender Age
# F      child                  4.0                 5.0
#        middle                14.0                16.0
#        old                   14.0                16.0
#        senior                14.0                16.0
#        young                 14.0                16.0
# M      child                  2.0                16.0
#        middle                 8.0                16.0
#        old                    8.0                16.0
#        senior                 8.0                16.0
#        young                  8.0                16.0

# %%
for i in ['F','M']:
  if i == 'F':
    for j,v in zip(['child','young','middle','senior','old'],[4,14,14,14,14]):
      data.loc[(data['Product_Category_2'].isna()) & (data['Gender']==i)&(data['Age'] == j),'Product_Category_2'] = float(v)
  else :
    for j,v in zip(['child','young','middle','senior','old'],[2,8,8,8,8]):
      data.loc[(data['Product_Category_2'].isna()) & (data['Gender']==i)&(data['Age'] == j),'Product_Category_2'] = float(v)

# %%
data.isna().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2                 0
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
data.Product_Category_2.unique()
# Out:
# array([ 4.,  6., 14.,  8.,  2., 15., 16., 11.,  5.,  3., 12.,  9., 10.,
#        17., 13.,  7., 18.])

# %%
# for i in ['F','M']:
#   if i == 'F':
#     for j,v in zip(['child','young','middle','senior','old'],[5,16,16,16,16]):
#       data.loc[(data['Product_Category_3'].isna()) & (data['Gender']==i)&(data['Age'] == j),'Product_Category_3'] = float(v)
#   else :
#     for j,v in zip(['child','young','middle','senior','old'],[16,16,16,16,16]):
#       data.loc[(data['Product_Category_3'].isna()) & (data['Gender']==i)&(data['Age'] == j),'Product_Category_3'] = float(v)

# %%
data['Product_Category_3'] = np.where(data['Product_Category_3'].isna()
,np.where(((data['Gender']=='F') & (data['Age']=='child')),5,16),
         data['Product_Category_3'])

# %%
np.where(data['Product_Category_3'].isna()
,np.where(((data['Gender']=='F') & (data['Age']=='child')),5,16),
         data['Product_Category_3'])
# Out:
# array([ 5., 14.,  5., ..., 16., 16., 16.])

# %%
data.Age.unique()
# Out:
# array(['child', 'old', 'middle', 'senior', 'young'], dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category_1          550068 non-null  int64
#  9   Product_Category_2          550068 non-null  float64
#  10  Product_Category_3          550068 non-null  float64
#  11  Purchase                    550068 non-null  int64
# dtypes: float64(2), int64(5), object(5)
# ...

# %%
data['Gender']= pd.get_dummies(data['Gender'],drop_first = True,dtype = int)
# data.Gender.map({'F':0,'M':1})

# %%
data.head()
# Out:
#    User_ID Product_ID  Gender    Age  Occupation City_Category  \
# 0  1000001  P00069042       0  child          10             A
# 1  1000001  P00248942       0  child          10             A
# 2  1000001  P00087842       0  child          10             A
# 3  1000001  P00085442       0  child          10             A
# 4  1000002  P00285442       1    old          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 4.0                 5.0      8370
# 1                 6.0                14.0     15200
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#male 1 female 0
# Gender count
sns.countplot(x = data['Gender'], data = data, hue='Gender')
new_labels = ['Males', 'Females']
plt.xticks(ticks=[1, 0], labels=new_labels)
# Out:
# ([<matplotlib.axis.XTick at 0x7c1129328b20>,
# ...
#  [Text(1, 0, 'Males'), Text(0, 0, 'Females')])

# %%
#age count
sns.countplot(x = data['Age'], data = data, hue='Age')
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
#occupation count
sns.countplot(x=data['Occupation'], data=data, hue='Occupation')
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
#purchase by occupation
sns.catplot(x = 'Occupation', y = 'Purchase', data = data, kind = 'bar',hue='Gender',height=8,aspect=2)

# %%
data.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
# city v purchase
sns.catplot(x='City_Category', y='Purchase', data=data, kind='bar',hue='Gender')

# %%
# purchase by age
sns.catplot(x='Age', y='Purchase', data=data, kind='bar',hue='Gender')
plt.xticks(rotation=90)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'child'),
#   Text(1, 0, 'old'),
#   Text(2, 0, 'middle'),
#   Text(3, 0, 'senior'),
#   Text(4, 0, 'young')])

# %%
data.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
sns.catplot(x='Product_Category_1',y='Purchase',data=data,kind='bar',hue='Product_Category_1',height=8,aspect=2)

# %%
sns.catplot(x='Product_Category_2',y='Purchase',data=data,kind='bar',hue='Product_Category_2',height=8,aspect=2)

# %%
data.Product_Category_2.unique()
# Out:
# array([ 4.,  6., 14.,  8.,  2., 15., 16., 11.,  5.,  3., 12.,  9., 10.,
#        17., 13.,  7., 18.])

# %%
sns.catplot(x='Product_Category_2',y='Purchase',data=data,kind='box',hue='Gender',height=8,aspect=2)

# %%
sns.catplot(x='Product_Category_3',y='Purchase',data=data,kind='bar',hue='Product_Category_3',height=8,aspect=2)

# %%
data.Product_Category_3.unique()
# Out:
# array([ 5., 14., 16., 17.,  4., 15.,  8.,  9., 13.,  6., 12.,  3., 18.,
#        11., 10.])

# %%
data.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase'],
#       dtype='object')

# %%
temp = data.groupby('City_Category')['City_Category'].count()

# %%
plt.pie(temp,labels=temp.index,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7c1120d9cd90>,
# ...
#  [Text(0.7311977723577078, 0.8217967009541508, 'A'),
#   Text(-1.0901451152986832, 0.14691367393956623, 'B'),
#   Text(0.6148894666805983, -0.9120915215948724, 'C')],
#  [Text(0.39883514855874963, 0.4482527459749913, '26.9%'),
#   Text(-0.5946246083447362, 0.08013473123976338, '42.0%'),
#   Text(0.33539425455305355, -0.4975044663244758, '31.1%')])

# %%
sns.catplot(x='Product_Category_3',y='Purchase',data=data,kind='violin',hue='Product_Category_3',height=8,aspect=2)

# %%
sns.catplot(x='Product_Category_3',y='Purchase',data=data,kind='boxen',hue='Product_Category_3',height=8,aspect=2)

# %%
sns.catplot(x='Product_Category_3',y='Purchase',data=data,kind='bar',hue='Product_Category_3',height=8,aspect=2)

# %%
data.head()
# Out:
#    User_ID Product_ID  Gender    Age  Occupation City_Category  \
# 0  1000001  P00069042       0  child          10             A
# 1  1000001  P00248942       0  child          10             A
# 2  1000001  P00087842       0  child          10             A
# 3  1000001  P00085442       0  child          10             A
# 4  1000002  P00285442       1    old          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 4.0                 5.0      8370
# 1                 6.0                14.0     15200
# ...
